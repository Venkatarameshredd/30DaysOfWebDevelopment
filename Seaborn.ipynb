# %% [markdown]
# <a href="https://colab.research.google.com/github/Venkatarameshredd/30DaysOfWebDevelopment/blob/main/Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
data=sns.load_dataset("iris")
sns.lineplot(x="sepal_length",y="sepal_width",data=data)
sns
# Out:
# <module 'seaborn' from '/usr/local/lib/python3.11/dist-packages/seaborn/__init__.py'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data=sns.load_dataset("iris")
sns.lineplot(x="sepal_length",y="sepal_width",data=data)
plt.title("Title using matplotlib")
plt.xlim(5)
plt.ylim(3)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data=sns.load_dataset("iris")
sns.lineplot(x="sepal_length",y="sepal_width",data=data)
sns.set_style("whitegrid")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data=sns.load_dataset("iris")
plt.figure(figsize=(2,4))
sns.lineplot(x="sepal_length",y="sepal_width",data=data)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data=sns.load_dataset("iris")
def plot():
     sns.lineplot(x="sepal_length",y="sepal_width",data=data)
with sns.axes_style("darkgrid"):
  plt.subplot(211)
  plot()

plt.subplot(212)
plot()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
palette=sns.color_palette()
sns.palplot(palette)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
palette=sns.color_palette('PiYG',11)
sns.palplot(palette)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
palette=sns.color_palette('Greens',11)
sns.palplot(palette)
plt.show()
